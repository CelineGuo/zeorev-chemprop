# %%
# import pandas as pd
# from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score, confusion_matrix

# %%
# pred_path = "/home/CelineGuo73/zeolites/ranking/chemprop-v1-old-branches/save_models/add_data/weight_fix_zeodb_01/Zeolite_Type/lev1_candidates_threshold_comb.csv"
# true_path = "/home/CelineGuo73/zeolites/data/all_data_ori.csv"

# pred_df = pd.read_csv(pred_path)
# true_df = pd.read_csv(true_path)

# pred_df.columns = [c.strip().lower() for c in pred_df.columns]
# true_df.columns = [c.strip().lower() for c in true_df.columns]

# %%
# import matplotlib.pyplot as plt
# import seaborn as sns

# plt.figure(figsize=(8,5))
# sns.histplot(pred_df["normalized_yield"], bins=30, kde=True, color="steelblue")
# plt.axvline(0.7, color="red", linestyle="--", label="Threshold 0.7")
# plt.title("Predicted Probability Distribution (AHT)")
# plt.xlabel("Predicted probability")
# plt.ylabel("Count of OSDAs")
# plt.legend()
# plt.tight_layout()
# plt.show()

# %%
# true_mfi = true_df[true_df["zeolite_code"].str.upper() == "AHT"].copy()

# threshold = 0.1
# pred_osda_col = "osda" if "osda" in pred_df.columns else "smiles"
# pred_osdas = set(pred_df.loc[pred_df["normalized_yield"] >= threshold, pred_osda_col].astype(str))
# true_osdas = set(true_mfi["osda"].astype(str))

# unique_osdas = set()  # to collect individual unique OSDAs

# for combo in true_osdas:
#     # split by dot, strip whitespace, ignore empty entries
#     parts = [p.strip() for p in combo.split(".") if p.strip()]
#     unique_osdas.update(parts)  # add each OSDA individually

# # convert to sorted list (optional, for readability)
# unique_osdas = sorted(unique_osdas)

# %%
# tp_set = true_osdas & pred_osdas
# fp_set = pred_osdas - true_osdas
# fn_set = true_osdas - pred_osdas
# tn = 0

# %%
# universe = sorted(true_osdas | pred_osdas)
# y_true = [1 if x in true_osdas else 0 for x in universe]
# y_pred = [1 if x in pred_osdas else 0 for x in universe]

# %%
# precision = precision_score(y_true, y_pred)
# recall = recall_score(y_true, y_pred)
# f1 = f1_score(y_true, y_pred)
# acc = accuracy_score(y_true, y_pred)
# cm = confusion_matrix(y_true, y_pred)

# %%
# print("=== SOD Zeolite Prescreen Evaluation ===")
# print(f"Threshold: {threshold}")
# print(f"Total true OSDAs: {len(unique_osdas)}") 
# print(f"Predicted OSDAs ≥ {threshold}: {len(pred_osdas)}")
# print(f"Recovered true OSDAs: {len(tp_set)} ({len(tp_set)/len(unique_osdas)*100:.2f}%)\n")
# print(f"From predicted OSDAs, there are {len(tp_set)/len(pred_osdas)*100:.2f}% true data")

# %% [markdown]
# ## PLOTTING

# %%
# MFI = 25.77
# AFI = 49.28
# BEA = 12.26
# SOD = 10.00
# AEI = 6.72
# MOR = 10.48

# %%
# import pandas as pd
# import matplotlib.pyplot as plt

# data = {
#     "Zeolite": ["MFI", "AFI", "BEA", "SOD", "AEI", "MOR"],
#     "True_OSDAs": [212, 528, 161, 52, 53, 115],
#     "Recovered_true": [67, 102, 32, 5, 9, 13],
#     "Predicted_≥0.7": [260, 207, 261, 50, 134, 124],
#     "Recovery_%": [31.6, 19.32, 19.88, 9.63, 16.98, 11.3]
# }

# %%
# df = pd.DataFrame(data)
# x = range(len(df))
# width = 0.25

# %%
# fig, ax1 = plt.subplots(figsize=(9, 5))
# ax1.bar([p - width for p in x], df["True_OSDAs"], width=width, label="True OSDAs", color="#4c72b0")
# ax1.bar(x, df["Predicted_≥0.7"], width=width, label="Predicted ≥0.7", color="#55a868")
# ax1.bar([p + width for p in x], df["Recovered_true"], width=width, label="Recovered True", color="#c44e52")

# ax1.set_xticks(x)
# ax1.set_xticklabels(df["Zeolite"])
# ax1.set_ylabel("Count")
# ax1.set_title("Prescreening Summary per Zeolite (Threshold ≥ 0.7)")
# ax1.legend(loc="upper left")

# plt.grid(axis="y", linestyle="--", alpha=0.5)
# plt.tight_layout()
# plt.show()

# %%
##RANKING HIT RATE

# %%
import pandas as pd

pred_path = "/home/CelineGuo73/zeolites/ranking/chemprop-v1-old-branches/save_models/add_data/0.1CLLnorm_weight_fix/Zeolite_Type/SSF/ssf1_candidates_threshold_comb.csv"
true_path = "/home/CelineGuo73/zeolites/data/all_data_ori.csv"
# true_path = "/home/CelineGuo73/zeolites/data/zeosyn_only.csv"

pred_df = pd.read_csv(pred_path)
true_df = pd.read_csv(true_path)

pred_df.columns = [c.strip().lower() for c in pred_df.columns]
true_df.columns = [c.strip().lower() for c in true_df.columns]

# %%
#Select all_data_ori with yield !=0
zeo_code = "SSF"
true_df = true_df[true_df["class"] != 0.0].copy()

true_osdas = set(true_df.loc[true_df["zeolite_code"] == zeo_code, "osda"].astype(str).unique())
print(f"Number of true OSDAs for {zeo_code}: {len(true_osdas)}")
# Out:
# Number of true OSDAs for SSF: 1153

# %%
##HIT RATE
top_n = [1,5,10,20,50,100,200]
hit_rates = {}
metrics = {}

for n in top_n:
    top_pred_osdas = set(pred_df.nsmallest(n, "rankinslate")["osda"].astype(str))
    hits = len(true_osdas & top_pred_osdas)

    # Precision = hits / N  → labeled as Hit Rate
    hit_rate = hits / n * 100

    # Recall = hits / total true  → labeled as Recovery
    recovery = hits / len(true_osdas) * 100 if len(true_osdas) > 0 else 0

    metrics[n] = (hit_rate, recovery)

# Print results
print("\n=== MFI Zeolite Ranking Metrics ===")
for n, (hit_rate, recovery) in metrics.items():
    print(f"Top {n}:  Hit Rate = {hit_rate:.2f}%   Recovery = {recovery:.2f}%")
# Out:
# === MFI Zeolite Ranking Metrics ===
# Top 1:  Hit Rate = 100.00%   Recovery = 0.09%
# Top 5:  Hit Rate = 100.00%   Recovery = 0.43%
# Top 10:  Hit Rate = 100.00%   Recovery = 0.87%
# Top 20:  Hit Rate = 90.00%   Recovery = 1.56%
# Top 50:  Hit Rate = 96.00%   Recovery = 4.16%
# Top 100:  Hit Rate = 82.00%   Recovery = 7.11%
# Top 200:  Hit Rate = 81.00%   Recovery = 14.05%

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# -----------------------------
# Data
# -----------------------------
# zeosyn_only = {
#     "Zeolite": ["LEV", "SOD", "AFI", "MFI", "BEA", "FER", "ERI"],
#     "Top-1": [0, 100, 0, 0, 0, 0, 0],
#     "Top-5": [0, 40, 0, 20, 0, 0, 0],
#     "Top-10": [0, 20, 20, 30, 0, 0, 0],
#     "Top-20": [0, 20, 30, 45, 0, 0, 0],
#     "Top-50": [0, 14, 38, 38, 4, 10, 0],
#     "Top-100": [0, 9, 35, 42, 9, 11, 2]
# }

# zeosyn_osdb = {
#     "Zeolite": ["LEV", "SOD", "AFI", "MFI", "BEA", "FER", "ERI"],
#     "Top-1": [100, 100, 0, 0, 0, 0, 100],
#     "Top-5": [60, 40, 40, 20, 60, 20, 80],
#     "Top-10": [40, 30, 40, 30, 60, 20, 60],
#     "Top-20": [20, 30, 45, 50, 65, 25, 35],
#     "Top-50": [28, 26, 56, 54, 58, 34, 22],
#     "Top-100": [35, 18, 50, 54, 48, 30, 29]
# }

zeosyn_only = {
    "Zeolite": ["LEV", "SOD", "MFI", "AFS", "SOV", "CHA", "VFI"],
    "Top-1": [0, 0, 100, 100, 0, 100, 0],
    "Top-5": [0, 60, 60, 100, 20, 100, 0],
    "Top-10": [0, 50, 60, 100, 50, 60, 50],
    "Top-20": [0, 55, 70, 100, 75, 55, 75],
    "Top-50": [0, 56, 86, 98, 86, 36, 88],
    "Top-100": [1, 35, 81, 98, 92, 45, 94],
    "#True Data in Training": [429, 79, 960, 1102, 1043, 788, 1070]
}

zeosyn_osdb = {
    "Zeolite": ["LEV", "SOD", "MFI", "AFS", "SOV", "CHA", "VFI"],
    "Top-1": [0, 100, 0, 0, 0, 0, 0],
    "Top-5": [0, 60, 60, 60, 20, 20, 60],
    "Top-10": [0, 80, 70, 70, 40, 20, 70],
    "Top-20": [0, 55, 80, 85, 45, 45, 85],
    "Top-50": [1, 40, 84, 86, 70, 52, 88],
    "Top-100": [4.5, 37, 87, 9, 80, 57, 91],
    "#True Data in Training": [429, 79, 960, 1102, 1043, 788, 1070]
}

# -----------------------------
# Convert to DataFrame
# -----------------------------
df1 = pd.DataFrame(zeosyn_only).set_index("Zeolite")
topk_df1 = df1.loc[:, df1.columns.str.contains("Top")]

df2 = pd.DataFrame(zeosyn_osdb).set_index("Zeolite")
topk_df2 = df2.loc[:, df2.columns.str.contains("Top")]

# -----------------------------
# Plot heatmaps
# -----------------------------
fig, axes = plt.subplots(1, 2, figsize=(29, 8))
sns.set(style="whitegrid")


sns.heatmap(topk_df1, annot=True, fmt=".1f", cmap="YlGn", cbar=True, vmin=0, vmax=100, ax=axes[0])
axes[0].set_title("ListNET Hit Rate (%)", fontsize=14)
axes[0].set_xlabel("Top-K")
axes[0].set_ylabel("Zeolite")
# -----------------------------
# Add number of training data next to y-axis labels
# -----------------------------
axes[0].set_yticklabels([f"{zeo} ({int(df1.loc[zeo, '#True Data in Training'])})" for zeo in df1.index], rotation=0)
##no need to include the last column in the heatmap
df1.drop(columns=["#True Data in Training"], inplace=True)

sns.heatmap(topk_df2, annot=True, fmt=".1f", cmap="YlGn", cbar=True, vmin=0, vmax=100, ax=axes[1])
axes[1].set_title("ListNET + InfoNCE Hit Rate (%)", fontsize=14)
axes[1].set_xlabel("Top-K")
axes[1].set_ylabel("")
axes[1].set_yticklabels([f"{zeo} ({int(df2.loc[zeo, '#True Data in Training'])})" for zeo in df2.index], rotation=0)

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# -----------------------------
# Data
# -----------------------------
# zeosyn_only = {
#     "Zeolite": ["LEV", "SOD", "AFI", "MFI", "BEA", "FER", "ERI"],
#     "Top-1": [0, 100, 0, 0, 0, 0, 0],
#     "Top-5": [0, 40, 0, 20, 0, 0, 0],
#     "Top-10": [0, 20, 20, 30, 0, 0, 0],
#     "Top-20": [0, 20, 30, 45, 0, 0, 0],
#     "Top-50": [0, 14, 38, 38, 4, 10, 0],
#     "Top-100": [0, 9, 35, 42, 9, 11, 2]
# }

# zeosyn_osdb = {
#     "Zeolite": ["LEV", "SOD", "AFI", "MFI", "BEA", "FER", "ERI"],
#     "Top-1": [100, 100, 0, 0, 0, 0, 100],
#     "Top-5": [60, 40, 40, 20, 60, 20, 80],
#     "Top-10": [40, 30, 40, 30, 60, 20, 60],
#     "Top-20": [20, 30, 45, 50, 65, 25, 35],
#     "Top-50": [28, 26, 56, 54, 58, 34, 22],
#     "Top-100": [35, 18, 50, 54, 48, 30, 29]
# }

zeosyn_only = {
    "Zeolite": ["LEV", "SOD", "MFI", "AFS", "SOV", "CHA", "VFI"],
    "Top-1": [0, 0, 100, 100, 0, 100, 0],
    "Top-5": [0, 60, 60, 100, 20, 100, 0],
    "Top-10": [0, 50, 60, 100, 50, 60, 50],
    "Top-20": [0, 55, 70, 100, 75, 55, 75],
    "Top-50": [0, 56, 86, 98, 86, 36, 88],
    "Top-100": [1, 35, 81, 98, 92, 45, 94],
    "#True Data in Training": [429, 79, 960, 1102, 1043, 788, 1070]
}

zeosyn_osdb = {
    "Zeolite": ["LEV", "SOD", "MFI", "AFS", "SOV", "CHA", "VFI"],
    "Top-1": [0, 100, 0, 0, 0, 0, 0],
    "Top-5": [0, 60, 60, 60, 20, 20, 60],
    "Top-10": [0, 80, 70, 70, 40, 20, 70],
    "Top-20": [0, 55, 80, 85, 45, 45, 85],
    "Top-50": [1, 40, 84, 86, 70, 52, 88],
    "Top-100": [4.5, 37, 87, 9, 80, 57, 91],
    "#True Data in Training": [429, 79, 960, 1102, 1043, 788, 1070]
}

# -----------------------------
# Convert to DataFrame
# -----------------------------
df1 = pd.DataFrame(zeosyn_only).set_index("Zeolite")
topk_df1 = df1.loc[:, df1.columns.str.contains("Top")]

df2 = pd.DataFrame(zeosyn_osdb).set_index("Zeolite")
topk_df2 = df2.loc[:, df2.columns.str.contains("Top")]

# -----------------------------
# Plot heatmaps
# -----------------------------
fig, axes = plt.subplots(1, 2, figsize=(29, 8))
sns.set(style="whitegrid")


sns.heatmap(topk_df1, annot=True, fmt=".1f", cmap="YlGn", cbar=True, vmin=0, vmax=100, ax=axes[0])
axes[0].set_title("ListNET Hit Rate (%)", fontsize=14)
axes[0].set_xlabel("Top-K")
axes[0].set_ylabel("Zeolite")
# -----------------------------
# Add number of training data next to y-axis labels
# -----------------------------
axes[0].set_yticklabels([f"{zeo} ({int(df1.loc[zeo, '#True Data in Training'])})" for zeo in df1.index], rotation=0)
##no need to include the last column in the heatmap
df1.drop(columns=["#True Data in Training"], inplace=True)

sns.heatmap(topk_df2, annot=True, fmt=".1f", cmap="YlGn", cbar=True, vmin=0, vmax=100, ax=axes[1])
axes[1].set_title("ListNET + InfoNCE Hit Rate (%)", fontsize=14)
axes[1].set_xlabel("Top-K")
axes[1].set_ylabel("")
axes[1].set_yticklabels([f"{zeo} ({int(df2.loc[zeo, '#True Data in Training'])})" for zeo in df2.index], rotation=0)

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# -----------------------------
# Data
# -----------------------------
data = {
    "Zeolite": [
        "LEV", "SOD", "AFI", "MFI", "BEA", "FER", "ERI", "AFS", "SOV", "DOH",
        "CHA", "SVR", "SVY", "TER", "THO", "VFI", "SSF"
    ],
    "Top-1 (%)":  [
        0,   100, 100, 100, 100, 100, 0,   100, 100, 0,
        0,   0,   0,   0,   0,   100, 100
    ],
    "Top-5 (%)":  [
        0,   100, 100, 80,  60,  20,  0,   100, 60,  60,
        0,   0,   0,   40,  40,  80,  100
    ],
    "Top-10 (%)": [
        0,   60,  80,  90,  60,  30,  10,  100, 70,  50,
        20,  0,   0,   60,  50,  60,  100
    ],
    "Top-20 (%)": [
        0,   65,  90,  90,  55,  30,  25,  100, 80,  40,
        35,  0,   0,   55,  70,  50,  90
    ],
    "Top-50 (%)": [
        6,   66,  92,  85,  56,  24,  18,  90,  74,  32,
        20,  0,   0,   48,  60,  62,  96
    ],
    "Top-100 (%)": [
        5,   40,  93,  68,  57,  18,  13,  93,  82,  29,
        24,  0,   0.5, 47,  53,  60,  82
    ],
    "#True Data in Training": [
        429, 79, 901, 960, 963, 252, 751, 1102, 1043, 86,
        788, 1,  13,  198, 66, 1070, 1153
    ]
}


df = pd.DataFrame(data).set_index("Zeolite")

# Sort by number of training data
df_sorted = df.sort_values(by="#True Data in Training", ascending=False)

# Extract only Top-K columns
topk_df = df_sorted.loc[:, df_sorted.columns.str.contains("Top")]

# -----------------------------
# Plot heatmap with training counts
# -----------------------------
plt.figure(figsize=(12, 8))
sns.set(style="whitegrid")

ax = sns.heatmap(
    topk_df,
    annot=True, fmt=".0f",
    cmap="YlGn",
    cbar_kws={'label': 'Hit Rate (%)'},
    linewidths=0.5,
    vmin=0, vmax=100
)

# Add title and labels
ax.set_title("Zeolite Top-K Hit Rate (%) (Ordered by Training Data Volume)", fontsize=15, pad=16)
ax.set_xlabel("Top-K")
ax.set_ylabel("Zeolite")

# -----------------------------
# Add number of training data next to y-axis labels
# -----------------------------
ax.set_yticklabels(
    [f"{label.get_text()}  ({df_sorted.loc[label.get_text(), '#True Data in Training']})"
     for label in ax.get_yticklabels()],
    rotation=0
)

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# -----------------------------
# Data
# -----------------------------
data = {
    "Zeolite": ["LEV", "SOD", "AFI", "MFI", "BEA", "FER", "ERI", "AFS", "SOV", "DOH",
                "CHA", "SVR", "SVY", "TER", "THO", "VFI", "SSF"],

    "Top-1 (%)":      [0, 100, 100, 100, 100, 100, 0, 100, 100, 0, 0, 0, 0, 0, 0, 100, 100],
    "Top-5 (%)":      [0, 60, 100, 100, 80, 60, 0, 80, 100, 0, 0, 0, 0, 0, 0, 100, 100],
    "Top-10 (%)":     [0, 30, 100, 100, 80, 70, 10, 90, 100, 0, 10, 0, 0, 10, 10, 100, 100],
    "Top-20 (%)":     [5, 15, 90, 95, 70, 75, 40, 95, 95, 0, 40, 0, 0, 25, 35, 95, 95],
    "Top-50 (%)":     [6, 6, 90, 78, 56, 64, 76, 92, 98, 4, 76, 0, 0, 28, 46, 92, 98],
    "Top-100 (%)":    [12, 3, 94, 81, 52, 53, 78, 83, 94, 4, 78, 0, 0, 26, 49, 99, 99],

    "#True Data in Training": [
        429, 79, 901, 960, 963, 252, 751, 1102, 1043, 86,
        788, 1, 13, 198, 66, 1070, 1153
    ]
}


df = pd.DataFrame(data)

# -----------------------------
# Compute mean Top-K hit rate
# -----------------------------
topk_cols = [col for col in df.columns if "Top" in col]
df["Mean Top-K (%)"] = df[topk_cols].mean(axis=1)

# -----------------------------
# Scatter + regression plot
# -----------------------------
plt.figure(figsize=(8, 6))
sns.set(style="whitegrid")

ax = sns.regplot(
    data=df,
    x="#True Data in Training",
    y="Mean Top-K (%)",
    scatter_kws={"s": 80, "color": "#2b83ba"},
    line_kws={"color": "#d7191c", "lw": 2}
)

# Annotate points with zeolite codes
for i, row in df.iterrows():
    ax.text(row["#True Data in Training"] + 10, row["Mean Top-K (%)"] + 1, row["Zeolite"],
            fontsize=9, color="black", alpha=0.7)

ax.set_xscale("log")  # Log scale helps spread uneven data
ax.set_xlabel("Number of True Data in Training", fontsize=12)
ax.set_ylabel("Mean Top-K Hit Rate (%)", fontsize=12)
ax.set_title("Relationship between Training Data Volume and Top-K Performance", fontsize=14)
plt.tight_layout()
plt.show()
